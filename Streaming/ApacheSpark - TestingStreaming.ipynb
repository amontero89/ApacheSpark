# %% [markdown]
# # Apache Spark - Testing Streaming

# %% [markdown]
# <p><strong>Objetivo: </strong> El objetivo de este cuaderno es utilizar la API de Dataframe para crear un ejemplo de uso de streaming estructurado:</p>

# %% [markdown]
# <p><strong>Nota: </strong> Para ejecutar este notebook es necesario utilizar versión 5.5 de Spark. Posteriores no permiten creación de archivos.</p>

# %% [markdown]
# ##Generando datos para consumo

# %% [markdown]
# En este ejemplo se estarán generando datos ejemplos en formato JSON para luego consumirlos en forma de streaming. El primer paso a seguir es crear una carpeta <b>streamtst</b> para depositar los archivos. Pueden crear la carpeta directamente sobre FileStore:

# %%
dbutils.fs.mkdirs('/FileStore/streamtst')
# Out:
# Out[1]: True

# %% [markdown]
# Para generar los datos de prueba se crea un diccionario simple con dos columnas. El primero, <b>unix_timestamp</b>, se completa con el tiempo actual. El segundo se llena con un número aleatorio <b>random_number</b>. Se convierte el resultado a formato JSON y se ubica el resultado en la carpeta <b>streamtst</b>. El comando del sistema de archivos enumerará todo en la carpeta streamtst. Solo debería haber un archivo en la carpeta, 0.json. Cada archivo tendrá un marca de tiempo y un número aleatorio. Por el momento solo se creará un archivo:

# %%
import json
import random
import time
d = {'unix_timestamp':time.time(),'random_number':random.randint(1,10)}
with open("/dbfs/FileStore/streamtst/0.json", "w") as f:
  json.dump(d, f)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# %fs ls /FileStore/streamtst/
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>path</th><th>name</th><th>size</th></tr></thead><tbody><tr><td>dbfs:/FileStore/streamtst/0.json</td><td>0.json</td><td>58</td></tr></tbody></table></div>

# %% [markdown]
# ##Configurar el stream

# %% [markdown]
# A continuacion se va a definir el esquema para que Databricks sepa con qué se está trabajado y sea más fácil el procesamiento:

# %%
from pyspark.sql.types import TimestampType, IntegerType, StructType, StructField
schema = StructType([
StructField("unix_timestamp", TimestampType(), True),
StructField("random_number", IntegerType(), True) ])
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# En este paso se puede definir el <b>readStream</b>, que se asigna el esquema, se establece que se leerá un archivo en cada trigger(por defecto son 1000), el formato y localización de los datos. Solo definimos la configuración, todavía no ocurre nada:

# %%
streamingDF = (
  spark
    .readStream
    .schema(schema)
    .option('maxFilesPerTrigger',1)
    .json('/FileStore/streamtst/')
)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# En este paso se configura una consulta de una agregación simple donde se cuenta el número de ocurrencias de cada número aleatorio:

# %%
streamingDFAgg = (streamingDF.groupBy(streamingDF.random_number).count())
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# ##Iniciar el flujo stream

# %% [markdown]
# Una vez que está todo definido se puede iniciar el stream. Se creará una tabla llamada <b>ramdom_numbers</b> y se va a depositar en la memoria. El parámetro <b>outputMode</b> define lo que se enviará al llamado sumidero o destino (en este caso, la memoria), se puede elegir entre Append, Update y Complete. Cómo se va a realizar una Agregación, es necesario utilizar Complete:

# %%
dfrun = (
  streamingDFAgg
    .writeStream
    .format("memory")
    .queryName("random_numbers")
    .outputMode("complete")
    .start()
)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# Ejecute la siguiente consulta para visualizar la cantidad de números que se obtuvieron de los datos. Configure un gráfico con <b>KEYS=random_number</b> y <b>VALUES=count</b>:

# %%
# %sql select * from random_numbers;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>random_number</th><th>count</th></tr></thead><tbody><tr><td>8</td><td>1</td></tr></tbody></table></div>

# %% [markdown]
# El proceso de streaming que se ha configurado solo ha leido un archivo, el que está en la carpeta actual. Se van a agregar más archivos para ver el proceso en funcionamiento. Para ellos ejecute el siguiente código que ubicará más archivos en la carpeta <b>streamtst</b>:

# %%
for i in range(1,100):
  d = {'unix_timestamp':time.time()
    ,'random_number':random.randint(1,10)}
  with open('/dbfs/FileStore/streamtst/{}.json'.format(i), 'w') as f:
    json.dump(d, f)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# Ahora puede visualizar que hay muchos más archivos dentro de la carpeta, y el proceso de streaming comenzará a leerlos:

# %%
# %fs ls /FileStore/streamtst/
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>path</th><th>name</th><th>size</th></tr></thead><tbody><tr><td>dbfs:/FileStore/streamtst/0.json</td><td>0.json</td><td>58</td></tr><tr><td>dbfs:/FileStore/streamtst/1.json</td><td>1.json</td><td>58</td></tr><tr><td>dbfs:/FileStore/streamtst/10.json</td><td>10.json</td><td>57</td></tr><tr><td>dbfs:/FileStore/streamtst/11.json</td><td>11.json</td><td>58</td></tr><tr><td>dbfs:/FileStore/streamtst/12.json</td><td>12.json</td><td>57</td></tr><tr><td>dbfs:/FileStore/streamtst/13.json</td><td>13.json</td><td>57</td></tr><tr><td>dbfs:/FileStore/streamtst/14.json</td><td>14.json</td><td>59</td></tr><tr><td>dbfs:/FileStore/streamtst/15.json</td><td>15.json</td><td>57</td></tr><tr><td>dbfs:/FileStore/streamtst/16.json</td><td>16.json</td><td>58</td></tr><tr><td>dbfs:/FileStore/streamtst/17.json</td><td>17.json</td><td>57</td></tr><tr><td>dbfs:/FileStore/streamtst/18.json</td><td>18.json</td><td>58</td></tr><tr><td>dbfs:/FileStore/streamtst/19.json</td><td>19.json</td><td>58</td></tr><tr><td>dbfs:/FileStore/streamtst/2.json</td><td>2.json</td><td>58</td></tr><tr><td>dbfs:/FileStore/streamtst/20.json</td><td>20.json</td><td>58</td></tr><tr><td>dbfs:/FileStore/streamtst/21.json</td><td>21.json</td><td>58</td></tr><tr><td>dbfs:/FileStore/streamtst/22.json</td><td>22.json</td><td>58</td></tr><tr><td>dbfs:/FileStore/streamtst/23.json</td><td>23.json</td><td>58</td></tr><tr><td>dbfs:/FileStore/streamtst/24.json</td><td>24.json</td><td>57</td></tr><tr><td>dbfs:/FileStore/streamtst/25.json</td><td>25.json</td><td>58</td></tr><tr><td>dbfs:/FileStore/streamtst/26.json</td><td>26.json</td><td>57</td></tr><tr><td>dbfs:/FileStore/streamtst/27.json</td><td>27.json</td><td>58</td></tr><tr><td>dbfs:/FileStore/streamtst/28.json</td><td>28.json</td><td>58</td></tr><tr><td>dbfs:/FileStore/streamtst/29.json</td><td>29.json</td><td>58</td></tr><tr><td>dbfs:/FileStore/streamtst/3.json</td><td>3.json</td><td>58</td></tr><tr><td>dbfs:/FileStore/streamtst/30.json</td><td>30.json</td><td>58</td></tr><tr><td>dbfs:/FileStore/streamtst/31.json</td><td>31.json</td><td>58</td></tr><tr><td>dbfs:/FileStore/streamtst/32.json</td><td>32.json</td><td>58</td></tr><tr><td>dbfs:/FileStore/streamtst/33.json</td><td>33.json</td><td>58</td></tr><tr><td>dbfs:/FileStore/streamtst/34.json</td><td>34.json</td><td>58</td></tr><tr><td>dbfs:/FileStore/streamtst/35.json</td><td>35.json</td><td>58</td></tr><tr><td>dbfs:/FileStore/streamtst/36.json</td><td>36.json</td><td>58</td></tr><tr><td>dbfs:/FileStore/streamtst/37.json</td><td>37.json</td><td>58</td></tr><tr><td>dbfs:/FileStore/streamtst/38.json</td><td>38.json</td><td>58</td></tr><tr><td>dbfs:/FileStore/streamtst/39.json</td><td>39.json</td><td>57</td></tr><tr><td>dbfs:/FileStore/streamtst/4.json</td><td>4.json</td><td>58</td></tr><tr><td>dbfs:/FileStore/streamtst/40.json</td><td>40.json</td><td>58</td></tr><tr><td>dbfs:/FileStore/streamtst/41.json</td><td>41.json</td><td>58</td></tr><tr><td>dbfs:/FileStore/streamtst/42.json</td><td>42.json</td><td>58</td></tr><tr><td>dbfs:/FileStore/streamtst/43.json</td><td>43.json</td><td>59</td></tr><tr><td>dbfs:/FileStore/streamtst/44.json</td><td>44.json</td><td>59</td></tr><tr><td>dbfs:/FileStore/streamtst/45.json</td><td>45.json</td><td>58</td></tr><tr><td>dbfs:/FileStore/streamtst/46.json</td><td>46.json</td><td>58</td></tr><tr><td>dbfs:/FileStore/streamtst/47.json</td><td>47.json</td><td>58</td></tr><tr><td>dbfs:/FileStore/streamtst/48.json</td><td>48.json</td><td>59</td></tr><tr><td>dbfs:/FileStore/streamtst/49.json</td><td>49.json</td><td>58</td></tr><tr><td>dbfs:/FileStore/streamtst/5.json</td><td>5.json</td><td>59</td></tr><tr><td>dbfs:/FileStore/streamtst/50.json</td><td>50.json</td><td>58</td></tr><tr><td>dbfs:/FileStore/streamtst/51.json</td><td>51.json</td><td>58</td></tr><tr><td>dbfs:/FileStore/streamtst/52.json</td><td>52.json</td><td>59</td></tr><tr><td>dbfs:/Fi ...

# %% [markdown]
# Ejecute nuevamente la consulta anterior para ver los nuevos resultados y cómo se van agregando datos a los resultados calculados previamente:

# %%
# %sql select * from random_numbers ORDER BY random_number;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>random_number</th><th>count</th></tr></thead><tbody><tr><td>7</td><td>1</td></tr><tr><td>8</td><td>1</td></tr></tbody></table></div>

# %%
# %sql select * from random_numbers ORDER BY random_number;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>random_number</th><th>count</th></tr></thead><tbody><tr><td>4</td><td>1</td></tr><tr><td>5</td><td>1</td></tr><tr><td>7</td><td>1</td></tr><tr><td>8</td><td>1</td></tr></tbody></table></div>

# %% [markdown]
# ##Chequeando el estado del Stream

# %% [markdown]
# Si bien es bueno tener el proceso de streaming en ejecución si obtiene datos, mantiene el clúster en funcionamiento. Por lo tanto, puede resultar costoso si no se tiene cuidado. Si desea ver si se está ejecutando algún streaming, puede hacerse ejecutando este código. Hay un flujo de streaming en ejecución:

# %%
for stream in spark.streams.active:
  print("{}, {}".format(stream.name, stream.id))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">random_numbers, 3b1e08eb-66d3-4542-847c-af55f12b43f8
# </div>

# %% [markdown]
# Para detener el flujo debe utilizar el siguiente comando:

# %%
dfrun.stop()

# %% [markdown]
# Si desea detener todos los streams activos, puede ejecutar otra versión del comando anterior, cuidado de no detener nada por error:

# %%
for stream in spark.streams.active:
  stream.stop()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>

# %% [markdown]
# Un detalle interesante es que la tabla que configuramos sigue activa. Ya no se actualizará, pero puede consultarla siempre que no detenga el clúster ni lo elimine activamente.

# %% [markdown]
# ##Ejecutando un poco más rápido

# %% [markdown]
# En el ejemplo anterior limitamos la velocidad a un archivo por Trigger. Eso no es lo que se hace normalmente. Usualmente se deja que Databricks ejecute a un ritmo superior. Lo que se obtiene sin ningún ajuste es 1000. Intentémoslo. Se configuran nuevamente los Dataframes, pero ahora no se pone el límite de 1 fichero por Trigger:

# %%
streamingDF = (spark.readStream.schema(schema).option('maxFilesPerTrigger',50).json('/FileStore/streamtst/'))
streamingDFAgg = (streamingDF.groupBy(streamingDF.random_number).count())

dfrun = (
  streamingDFAgg
    .writeStream
    .format("memory")
    .queryName("random_numbers")
    .outputMode("complete")
    .start()
)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# Ejecute la consulta SQL nuevamente y compruebe que los resultados aparecen mucho más rápido:

# %%
# %sql select * from random_numbers ORDER BY random_number;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>random_number</th><th>count</th></tr></thead><tbody><tr><td>1</td><td>7</td></tr><tr><td>2</td><td>9</td></tr><tr><td>3</td><td>2</td></tr><tr><td>4</td><td>6</td></tr><tr><td>5</td><td>6</td></tr><tr><td>6</td><td>4</td></tr><tr><td>7</td><td>4</td></tr><tr><td>8</td><td>5</td></tr><tr><td>9</td><td>1</td></tr><tr><td>10</td><td>6</td></tr></tbody></table></div>

# %% [markdown]
# ##Limpiando el espacio de trabajo

# %% [markdown]
# Si desea eliminar la carpeta y los archivos creados en el DBFS puede ejecutar el siguiente comando:

# %%
dbutils.fs.rm("/FileStore/streamtst/",True)
